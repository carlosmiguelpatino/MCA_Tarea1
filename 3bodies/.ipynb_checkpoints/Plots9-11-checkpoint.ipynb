# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t, q3, p3 = loadtxt('simplectic_results.txt', unpack=True)
figure(figsize=(40, 20))
scatter(q3, p3, s=1)
#xlim(-3.2, 3.2)
#ylim(-2.5, 2.5)
xlim(-2.4, -0.9)
ylim(-0.65, 0.65)
xlim(-0.25, 0.9)
ylim(-0.35, 0.35)
# Out:
# (-0.35, 0.35)

# %%
t, q3k, p3k = loadtxt('rk4_results.txt', unpack=True)
figure(figsize=(40, 20))
scatter(q3k, p3k, s=1)
#xlim(-3.2, 3.2)
#ylim(-2.5, 2.5)
xlim(-2.4, -0.9)
ylim(-0.65, 0.65)
xlim(-0.25, 0.9)
ylim(-0.35, 0.35)
# Out:
# (-0.35, 0.35)
