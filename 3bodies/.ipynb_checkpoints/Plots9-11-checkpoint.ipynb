# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
j_s, t_s, q3_s, p3_s, E_s = loadtxt('simplectic_results_911.txt', unpack=True)

# %%
figure(figsize=(40, 20))
scatter(q3_s, p3_s, s=1)
xlim(-3.2, 3.2)
ylim(-2.5, 2.5)
# Out:
# (-2.5, 2.5)

# %%
figure(figsize=(40, 20))
scatter(q3_s, p3_s, s=1)
xlim(-2.4, -0.9)
ylim(-0.65, 0.65)
# Out:
# (-0.65, 0.65)

# %%
figure(figsize=(40, 20))
scatter(q3_s, p3_s, s=1)
xlim(-0.25, 0.9)
ylim(-0.35, 0.35)
# Out:
# (-0.35, 0.35)

# %%
j_rk, t_rk, q3_rk, p3_rk, E_rk = loadtxt('rk4_results_911.txt', unpack=True)

# %%
figure(figsize=(40, 20))
scatter(q3_rk, p3_rk, s=1)
xlim(-3.2, 3.2)
ylim(-2.5, 2.5)
# Out:
# (-2.5, 2.5)

# %%
figure(figsize=(40, 20))
scatter(q3_rk, p3_rk, s=1)
xlim(-2.4, -0.9)
ylim(-0.65, 0.65)
# Out:
# (-0.65, 0.65)

# %%
figure(figsize=(40, 20))
scatter(q3_rk, p3_rk, s=1)
xlim(-0.25, 0.9)
ylim(-0.35, 0.35)
# Out:
# (-0.35, 0.35)
