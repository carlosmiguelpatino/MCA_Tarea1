# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t, q3, p3 = loadtxt('simplectic_results_1214.txt', unpack=True)
figure(figsize=(40, 20))
scatter(q3, p3, s=1)
xlim(-2, 2)
ylim(-2.5, 2.5)
# Out:
# (-2.5, 2.5)

# %%
figure(figsize=(40, 20))
scatter(q3, p3, s=1)
xlim(0.2, 0.7)
ylim(-0.65, 0.65)
# Out:
# (-0.65, 0.65)

# %%
figure(figsize=(40, 20))
scatter(q3, p3, s=1)
xlim(-0.08, 0.08)
ylim(-0.1, 0.1)
# Out:
# (-0.1, 0.1)
