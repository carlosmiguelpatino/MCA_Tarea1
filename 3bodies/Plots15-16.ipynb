# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
j_15, t_15, q3_15, p3_15 = loadtxt('simplectic_results_15.txt', unpack=True)

# %%
figure(figsize=(40, 20))
scatter(q3_15, p3_15, c=j_15, s=1, edgecolors='none')
xlim(-3.2, 3.2)
ylim(-2.5, 2.5)
# Out:
# (-2.5, 2.5)

# %%
j_16, t_16, q3_16, p3_16 = loadtxt('simplectic_results_16.txt', unpack=True)

# %%
figure(figsize=(40, 20))
scatter(q3_16, p3_16, c=j_16, s=1, edgecolors='none')
xlim(-3.2, 3.2)
ylim(-2.5, 2.5)
# Out:
# (-2.5, 2.5)
