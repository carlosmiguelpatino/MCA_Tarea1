# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
j_s, t_s, q3_s, p3_s, E_s = loadtxt('simplectic_results_911.txt', unpack=True)
j_rk, t_rk, q3_rk, p3_rk, E_rk = loadtxt('rk4_results_911.txt', unpack=True)

# %%
selected_indexes_s = np.where(j_s == 0) 
plot(t_s[selected_indexes_s], E_s[selected_indexes_s])

# %%
selected_indexes_rk = np.where(j_rk == 0) 
plot(t_rk[selected_indexes_rk], E_rk[selected_indexes_rk])
